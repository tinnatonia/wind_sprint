# %% [markdown]
# ## DATA SPRINT
# #### Wind Turbine Descriptive Statistics

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
wind = pd.read_csv('./jonas_sprint/datasets/wind_turbine_market.csv')

# %%
pd.set_option('display.max_column', None)
wind.head()
# Out:
#    case_id    faa_ors           faa_asn  usgs_pr_id   eia_id t_state  \
# 0  3072661        NaN               NaN      5149.0  52161.0      CA
# 1  3072695        NaN               NaN      5143.0  52161.0      CA
# 2  3072704        NaN               NaN      5146.0  52161.0      CA
# 3  3063272  19-028134  2014-WTE-4084-OE         NaN      NaN      IA
# 4  3053390  19-028015  2015-WTE-6386-OE         NaN      NaN      IA
#
#        t_county  t_fips                   p_name  p_year  p_tnum  p_cap  \
# 0   Kern County    6029                 251 Wind  1987.0     194  18.43
# 1   Kern County    6029                 251 Wind  1987.0     194  18.43
# 2   Kern County    6029                 251 Wind  1987.0     194  18.43
# 3  Story County   19169  30 MW Iowa DG Portfolio  2017.0      10  30.00
# 4  Boone County   19015  30 MW Iowa DG Portfolio  2017.0      10  30.00
#
#    t_manu     t_model   t_cap  t_hh   t_rd     t_rsa  t_ttlh  retrofit  \
# ...

# %%
pd.set_option('display.max_row', None)
wind['t_manu'].value_counts()
# Out:
# GE Wind                                                                     29137
# Vestas                                                                      16259
# Siemens                                                                      5035
# Gamesa                                                                       3077
# Mitsubishi                                                                   2620
# Siemens Gamesa Renewable Energy                                              2043
# Nordex                                                                       1591
# Suzlon                                                                       1316
# Acciona                                                                       758
# REpower                                                                       574
# NEG Micon                                                                     529
# ...

# %%
wind[['t_cap', 't_hh', 't_rd', 't_rsa', 't_ttlh']].describe()
# Out:
#               t_cap          t_hh          t_rd         t_rsa        t_ttlh
# count  65328.000000  64628.000000  64874.000000  64874.000000  64628.000000
# mean    1963.534151     81.054571     95.663717   7618.500657    129.050593
# std      717.067912     12.028726     23.424346   3309.229282     22.185981
# min       50.000000     19.000000     13.400000    141.030000     30.400000
# 25%     1500.000000     80.000000     82.000000   5281.020000    121.000000
# 50%     2000.000000     80.000000    100.000000   7853.980000    130.100000
# 75%     2300.000000     87.000000    110.000000   9503.320000    145.100000
# max     6000.000000    131.000000    155.000000  18869.190000    199.600000

# %%
ppsize=wind[['p_name', 'p_tnum']].groupby(by='p_name')
ppsize
