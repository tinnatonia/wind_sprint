# %% [markdown]
# ## DATA SPRINT
# #### Trends over Time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
wind = pd.read_csv('./datasets/wind_turbine_market.csv')

# %%
wind.shape
# Out:
# (70808, 27)

# %%
pd.set_option('display.max_column', None)
wind.head(2)
# Out:
#    case_id faa_ors faa_asn  usgs_pr_id   eia_id t_state     t_county  t_fips  \
# 0  3072661     NaN     NaN      5149.0  52161.0      CA  Kern County    6029
# 1  3072695     NaN     NaN      5143.0  52161.0      CA  Kern County    6029
#
#      p_name  p_year  p_tnum  p_cap  t_manu t_model  t_cap  t_hh  t_rd  t_rsa  \
# 0  251 Wind  1987.0     194  18.43  Vestas     NaN   95.0   NaN   NaN    NaN
# 1  251 Wind  1987.0     194  18.43  Vestas     NaN   95.0   NaN   NaN    NaN
#
#    t_ttlh  retrofit  retrofit_year  t_conf_atr  t_conf_loc  t_img_date  \
# 0     NaN         0            NaN           2           3  2018-05-08
# 1     NaN         0            NaN           2           3  2018-05-08
#
#       t_img_srce       xlong       ylat
# 0  Digital Globe -118.363762  35.077908
# 1  Digital Globe -118.364410  35.077435

# %%
wind.drop(columns=['faa_ors', 'faa_asn', 'usgs_pr_id', 't_img_srce', 't_img_date'], inplace=True)

# %%
cap_growth = wind[['p_year', 't_cap']].groupby(by='p_year', as_index=False).sum()
cap_growth
# Out:
#     p_year       t_cap
# 0   1981.0         0.0
# 1   1982.0       323.0
# 2   1983.0     28080.0
# 3   1984.0     10070.0
# 4   1985.0     25025.0
# 5   1986.0     10030.0
# 6   1987.0     19293.0
# 7   1988.0     17010.0
# 8   1989.0         0.0
# 9   1990.0       350.0
# 10  1991.0       225.0
# 11  1992.0       750.0
# 12  1994.0      4700.0
# 13  1995.0      4565.0
# 14  1996.0       600.0
# 15  1997.0     19490.0
# 16  1998.0    134650.0
# 17  1999.0    451030.0
# 18  2000.0     51155.0
# 19  2001.0   1666396.0
# 20  2002.0    403976.0
# 21  2003.0   1618050.0
# 22  2004.0    335560.0
# 23  2005.0   2369740.0
# 24  2006.0   2348870.0
# 25  2007.0   5298160.0
# 26  2008.0   8469830.0
# 27  2009.0   9900313.0
# 28  2010.0   5231510.0
# 29  2011.0   6833680.0
# 30  2012.0  13070820.0
# 31  2013.0   1088925.0
# 32  2014.0   4847988.0
# 33  2015.0   8590108.0
# 34  2016.0   8108947.0
# 35  2017.0   7009520.0
# 36  2018.0   7418135.0
# 37  2019.0   9095615.0
# 38  2020.0  17286530.0
# 39  2021.0   6501880.0

# %%
# To show overall growth of wind energy production by year

x = cap_growth['p_year']
y = cap_growth['t_cap']

plt.plot(x, y)
plt.title('Sum of Total Capacity Built Each Year')
plt.xlabel('Year')
plt.ylabel('Sum of Capacity (kW)')
plt.show()

# %%
t_size_growth = wind[['p_year', 't_hh', 't_rd', 't_rsa', 't_ttlh']].groupby(by='p_year', as_index=False).mean()
t_size_growth
# Out:
fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(x, y1)
axs[0, 0].set_title('Hub Height (m)')
axs[0, 1].plot(x, y2, 'tab:orange')
axs[0, 1].set_title('Rotor Diameter (m)')
axs[1, 0].plot(x, y3, 'tab:green')
axs[1, 0].set_title('Rotor Swept Area (m2)')
axs[1, 1].plot(x, y4, 'tab:red')
axs[1, 1].set_title('Total Height (m)')


for ax in axs.flat:
    ax.set(xlabel='year')

for ax in axs.flat:
    ax.label_outer()

# %%
pd.set_option('display.max_row', None)
top_manu = wind[['t_manu', 'p_tnum']].groupby(by='t_manu', as_index=False).sum().sort_values(by='p_tnum', ascending=False)
top_manu
# Out:
#                                                t_manu   p_tnum
# 20                                            GE Wind  2749868
# 56                                             Vestas  1824532
# 46                                            Siemens   405904
# 31                                         Mitsubishi   328824
# 21                                             Gamesa   253286
# 47                    Siemens Gamesa Renewable Energy   195012
# 34                                             Nordex   113077
# 51                                             Suzlon    57205
# 3                                             Acciona    56478
# 17                                              Enron    52509
# 7                                               Bonus    45098
# 30                                              Micon    44844
# 40                                            REpower    36063
# 36                                           Nordtank    26340
# 32                                          NEG Micon    22893
# 11                                            Clipper    20698
# 22                                           Goldwind     9353
# 62                                               Zond     3319
# 23                                  Goldwind Americas     2304
# 13                                             DeWind     2156
# 10                         China Creative Wind Energy      289
# 5                                              Alstom      288
# 18                                          Entegrity      274
# 37                             Northern Power Systems      231
# 33                                            NedWind      169
# 44                                               Sany      163
# 12                                                DWT      147
# 19                                         Fuhrlander      116
# 45                                           Seaforth       58
# 25                                       HZ Windpower       56
# 1                                                 AOC       53
# 54                                             Vensys       47
# 24                                            Guodian       36
# 55                                            Vergnet       27
# 61                                          Windmatic       26
# 29                                            Lolland       24
# 14                                                EWT       17
# 52                                         Turbowinds       15
# 57                                       Westinghouse       12
# 41                                                RRB       10
# 39                                          PowerWind        8
# 16                                          Endurance        7
# 26                                            Hyundai        6
# 49                                            Sinovel        6
# 4                                         Aeronautica        5
# 48                                       Silver Eagle        4
# 8                                                Bora        4
# 35                                             Nordic        4
# 0                                                AAER        4
# 43                                            Samsung        3
# 42                                      Renewtech LLC        2
# 50                                               Siva        2
# 53                                             Unison        2
# 2                                                 AWE        2
# 27                                           Kenersys        2
# 60                                         Wind World        2
# 15                                             Elecon        2
# 6                                       Bergey Energy        1
# 38                                             Norwin        1
# 9   Changzhou Railcar Propulsion Engineering Resea...        1
# 28                                       Leitner Poma        1
# 58                                             Wincon        1
# 59                              Wind Energy Solutions        1

# %%
pd.set_option('display.max_rows', None)
topwind = wind.apply(lambda row: row[wind['t_manu'].isin(['GE Wind', 'Vestas', 'Siemens', 'Mitsubishi', 'Gamesa', 'Siemens Gamesa Renewable Energy'])])
manu_growth = topwind[['p_year', 't_manu', 'p_tnum']].groupby(by=['p_year', 't_manu'], as_index=False).sum()
manu_growth
# Out:
#      p_year                           t_manu  p_tnum
# 0    1982.0                           Vestas       1
# 1    1983.0                           Vestas  198720
# 2    1985.0                           Vestas   14075
# 3    1986.0                           Vestas       4
# 4    1987.0                           Vestas     582
# 5    1991.0                           Vestas       1
# 6    1992.0                           Vestas     147
# 7    1994.0                           Vestas     660
# 8    1995.0                           Vestas     840
# 9    1996.0                           Vestas       1
# 83   2014.0                           Vestas   22080
# 84   2015.0                          GE Wind  210369
# 85   2015.0                           Gamesa   19226
# 86   2015.0                          Siemens   73746
# 87   2015.0                           Vestas  117186
# 88   2016.0                          GE Wind  166549
# 89   2016.0                           Gamesa    6286
# 90   2016.0                          Siemens   25964
# 91   2016.0                           Vestas  142208
# 92   2017.0                          GE Wind   72448
# 93   2017.0                           Gamesa   40281
# 94   2017.0                          Siemens   25473
# 95   2017.0                           Vestas  100252
# 96   2018.0                          GE Wind   97478
# 97   2018.0  Siemens Gamesa Renewable Energy   18519
# 98   2018.0                           Vestas  110025
# 99   2019.0                          GE Wind  152189
# 100  2019.0                          Siemens    8056
# 101  2019.0  Siemens Gamesa Renewable Energy   29840
# 102  2019.0                           Vestas  148611
# 103  2020.0                          GE Wind  303656
# 104  2020.0  Siemens Gamesa Renewable Energy   37311
# 105  2020.0                           Vestas  251759
# 106  2021.0                          GE Wind   69870
# 107  2021.0                           Gamesa     208
# 108  2021.0                          Siemens    8732
# 109  2021.0  Siemens Gamesa Renewable Energy   10758
# 110  2021.0                           Vestas   80323

# %%
# to view top manufacturers growth over time
vestas = manu_growth[manu_growth['t_manu'] == 'Vestas']
ge_wind = manu_growth[manu_growth['t_manu'] == 'GE Wind']
siemens = manu_growth[manu_growth['t_manu'] == 'Siemens']
mitsubishi = manu_growth[manu_growth['t_manu'] == 'Mitsubishi']
gamesa = manu_growth[manu_growth['t_manu'] == 'Gamesa']
siemens_gamesa = manu_growth[manu_growth['t_manu'] == 'Siemens Gamesa Renewable Energy']

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(12,4), sharey=True, sharex=True)

fig.set_facecolor('lightsteelblue') # addressing plt.figure

ax[0, 0].plot(vestas['p_year'], vestas['p_tnum'], color='c')
ax[0, 0].set_title('Vestas', fontsize=10)
ax[0, 1].plot(ge_wind['p_year'], ge_wind['p_tnum'], color='m')
ax[0, 1].set_title('GE Wind', fontsize=10)
ax[0, 2].plot(siemens['p_year'], siemens['p_tnum'], color='y')
ax[0, 2].set_title('Siemens', fontsize=10)
ax[1, 0].plot(mitsubishi['p_year'], mitsubishi['p_tnum'], color='c')
ax[1, 0].set_title('Mitsubishi', fontsize=10)
ax[1, 1].plot(gamesa['p_year'], gamesa['p_tnum'], color='m')
ax[1, 1].set_title('Gamesa', fontsize=10)
ax[1, 2].plot(siemens_gamesa['p_year'], siemens_gamesa['p_tnum'], color='y')
ax[1, 2].set_title('SGRE', fontsize=10)


# manu_names = ['Vestas', 'GE Wind', 'Siemens', 'Mitsubishi', 'Gamesa', 'Siemens Gamesa Renewable Energy']

# for i in range(len(ax)):
#     ax[i, i].set_xlabel('Year', fontsize=12)
#     ax[i, i].set_title(f'{manu_names[i]}', fontsize=16)
    
# ax.set_ylabel('Number of Turbines', fontsize=12)

fig.suptitle('Growth of Turbines by Manufacturers over Time', fontsize=14)
plt.tight_layout()
